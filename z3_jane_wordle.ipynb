# %%
# !pip install py-heat-magic z3-solver line_profiler
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: py-heat-magic in /home/ben/.local/lib/python3.9/site-packages (0.0.2)
# Requirement already satisfied: z3-solver in /home/ben/.local/lib/python3.9/site-packages (4.8.14.0)
# Requirement already satisfied: line_profiler in /home/ben/.local/lib/python3.9/site-packages (3.4.0)
# Requirement already satisfied: ipython in /home/ben/.local/lib/python3.9/site-packages (from py-heat-magic) (8.0.1)
# Requirement already satisfied: nose in /home/ben/.local/lib/python3.9/site-packages (from py-heat-magic) (1.3.7)
# Requirement already satisfied: numpy in /usr/lib/python3/dist-packages (from py-heat-magic) (1.21.5)
# Requirement already satisfied: sympy in /home/ben/.local/lib/python3.9/site-packages (from py-heat-magic) (1.9)
# Requirement already satisfied: jupyter in /home/ben/.local/lib/python3.9/site-packages (from py-heat-magic) (1.0.0)
# Requirement already satisfied: matplotlib in /home/ben/.local/lib/python3.9/site-packages (from py-heat-magic) (3.5.1)
# Requirement already satisfied: py-heat in /home/ben/.local/lib/python3.9/site-packages (from py-heat-magic) (0.0.6)
# Requirement already satisfied: scipy in /home/ben/.local/lib/python3.9/site-packages (from py-heat-magic) (1.7.3)
# Requirement already satisfied: pandas in /home/ben/.local/lib/python3.9/site-packages (from py-heat-magic) (1.4.0)
# Requirement already satisfied: decorator in /home/ben/.local/lib/python3.9/site-packages (from ipython->py-heat-magic) (5.1.1)
# Requirement already satisfied: traitlets>=5 in /home/ben/.local/lib/python3.9/site-packages (from ipython->py-heat-magic) (5.1.1)
# Requirement already satisfied: stack-data in /home/ben/.local/lib/python3.9/site-packages (from ipython->py-heat-magic) (0.1.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/ben/.local/lib/python3.9/site-packages (from ipython->py-heat-magic) (3.0.26)
# Requirement already satisfied: backcall in /home/ben/.local/lib/python3.9/site-packages (from ipython->py-heat-magic) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython->py-heat-magic) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /home/ben/.local/lib/python3.9/site-packages (from ipython->py-heat-magic) (0.18.1)
# Requirement already satisfied: black in /home/ben/.local/lib/python3.9/site-packages (from ipython->py-heat-magic) (22.1.0)
# Requirement already satisfied: pickleshare in /home/ben/.local/lib/python3.9/site-packages (from ipython->py-heat-magic) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/lib/python3/dist-packages (from ipython->py-heat-magic) (59.6.0)
# Requirement already satisfied: pygments in /home/ben/.local/lib/python3.9/site-packages (from ipython->py-heat-magic) (2.11.2)
# Requirement already satisfied: matplotlib-inline in /home/ben/.local/lib/python3.9/site-packages (from ipython->py-heat-magic) (0.1.3)
# Requirement already satisfied: nbconvert in /home/ben/.local/lib/python3.9/site-packages (from jupyter->py-heat-magic) (6.4.1)
# Requirement already satisfied: ipywidgets in /home/ben/.local/lib/python3.9/site-packages (from jupyter->py-heat-magic) (7.6.5)
# Requirement already satisfied: notebook in /home/ben/.local/lib/python3.9/site-packages (from jupyter->py-heat-magic) (6.4.8)
# Requirement already satisfied: qtconsole in /home/ben/.local/lib/python3.9/site-packages (from jupyter->py-heat-magic) (5.2.2)
# Requirement already satisfied: jupyter-console in /home/ben/.local/lib/python3.9/site-packages (from jupyter->py-heat-magic) (6.4.0)
# Requirement already satisfied: ipykernel in /home/ben/.local/lib/python3.9/site-packages (from jupyter->py-heat-magic) (6.8.0)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from matplotlib->py-heat-magic) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/lib/python3/dist-packages (from matplotlib->py-heat-magic) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /home/ben/.local/lib/python3.9/site-packages (from matplotlib->py-heat-magic) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ben/.local/lib/python3.9/site-packages (from matplotlib->py-heat-magic) (4.29.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib->py-heat-magic) (9.0.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ben/.local/lib/python3.9/site-packages (from matplotlib->py-heat-magic) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ben/.local/lib/python3.9/site-packages (from matplotlib->py-heat-magic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ben/.local/lib/python3.9/site-packages (from pandas->py-heat-magic) (2021.3)
# Requirement already satisfied: pprofile in /home/ben/.local/lib/python3.9/site-packages (from py-heat->py-heat-magic) (2.1.0)
# Requirement already satisfied: mpmath>=0.19 in /home/ben/.local/lib/python3.9/site-packages (from sympy->py-heat-magic) (1.2.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/ben/.local/lib/python3.9/site-packages (from jedi>=0.16->ipython->py-heat-magic) (0.8.3)
# Requirement already satisfied: wcwidth in /home/ben/.local/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->py-heat-magic) (0.2.5)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib->py-heat-magic) (1.16.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /home/ben/.local/lib/python3.9/site-packages (from black->ipython->py-heat-magic) (0.4.3)
# Requirement already satisfied: tomli>=1.1.0 in /home/ben/.local/lib/python3.9/site-packages (from black->ipython->py-heat-magic) (2.0.0)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /home/ben/.local/lib/python3.9/site-packages (from black->ipython->py-heat-magic) (4.0.1)
# Requirement already satisfied: platformdirs>=2 in /home/ben/.local/lib/python3.9/site-packages (from black->ipython->py-heat-magic) (2.4.1)
# Requirement already satisfied: pathspec>=0.9.0 in /home/ben/.local/lib/python3.9/site-packages (from black->ipython->py-heat-magic) (0.9.0)
# Requirement already satisfied: click>=8.0.0 in /home/ben/.local/lib/python3.9/site-packages (from black->ipython->py-heat-magic) (8.0.3)
# Requirement already satisfied: jupyter-client<8.0 in /home/ben/.local/lib/python3.9/site-packages (from ipykernel->jupyter->py-heat-magic) (7.1.2)
# Requirement already satisfied: tornado<7.0,>=4.2 in /home/ben/.local/lib/python3.9/site-packages (from ipykernel->jupyter->py-heat-magic) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /home/ben/.local/lib/python3.9/site-packages (from ipykernel->jupyter->py-heat-magic) (1.5.1)
# Requirement already satisfied: nest-asyncio in /home/ben/.local/lib/python3.9/site-packages (from ipykernel->jupyter->py-heat-magic) (1.5.4)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/ben/.local/lib/python3.9/site-packages (from ipywidgets->jupyter->py-heat-magic) (1.0.2)
# Requirement already satisfied: nbformat>=4.2.0 in /home/ben/.local/lib/python3.9/site-packages (from ipywidgets->jupyter->py-heat-magic) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/ben/.local/lib/python3.9/site-packages (from ipywidgets->jupyter->py-heat-magic) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/ben/.local/lib/python3.9/site-packages (from ipywidgets->jupyter->py-heat-magic) (0.2.0)
# Requirement already satisfied: defusedxml in /home/ben/.local/lib/python3.9/site-packages (from nbconvert->jupyter->py-heat-magic) (0.7.1)
# Requirement already satisfied: jinja2>=2.4 in /home/ben/.local/lib/python3.9/site-packages (from nbconvert->jupyter->py-heat-magic) (3.0.3)
# Requirement already satisfied: jupyter-core in /home/ben/.local/lib/python3.9/site-packages (from nbconvert->jupyter->py-heat-magic) (4.9.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/ben/.local/lib/python3.9/site-packages (from nbconvert->jupyter->py-heat-magic) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/ben/.local/lib/python3.9/site-packages (from nbconvert->jupyter->py-heat-magic) (0.5.10)
# Requirement already satisfied: bleach in /home/ben/.local/lib/python3.9/site-packages (from nbconvert->jupyter->py-heat-magic) (4.1.0)
# Requirement already satisfied: jupyterlab-pygments in /home/ben/.local/lib/python3.9/site-packages (from nbconvert->jupyter->py-heat-magic) (0.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/ben/.local/lib/python3.9/site-packages (from nbconvert->jupyter->py-heat-magic) (0.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/ben/.local/lib/python3.9/site-packages (from nbconvert->jupyter->py-heat-magic) (1.5.0)
# Requirement already satisfied: testpath in /home/ben/.local/lib/python3.9/site-packages (from nbconvert->jupyter->py-heat-magic) (0.5.0)
# Requirement already satisfied: prometheus-client in /home/ben/.local/lib/python3.9/site-packages (from notebook->jupyter->py-heat-magic) (0.13.1)
# Requirement already satisfied: terminado>=0.8.3 in /home/ben/.local/lib/python3.9/site-packages (from notebook->jupyter->py-heat-magic) (0.13.1)
# Requirement already satisfied: argon2-cffi in /home/ben/.local/lib/python3.9/site-packages (from notebook->jupyter->py-heat-magic) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/ben/.local/lib/python3.9/site-packages (from notebook->jupyter->py-heat-magic) (1.8.0)
# Requirement already satisfied: pyzmq>=17 in /home/ben/.local/lib/python3.9/site-packages (from notebook->jupyter->py-heat-magic) (22.3.0)
# Requirement already satisfied: qtpy in /home/ben/.local/lib/python3.9/site-packages (from qtconsole->jupyter->py-heat-magic) (2.0.1)
# Requirement already satisfied: asttokens in /home/ben/.local/lib/python3.9/site-packages (from stack-data->ipython->py-heat-magic) (2.0.5)
# Requirement already satisfied: pure-eval in /home/ben/.local/lib/python3.9/site-packages (from stack-data->ipython->py-heat-magic) (0.2.2)
# Requirement already satisfied: executing in /home/ben/.local/lib/python3.9/site-packages (from stack-data->ipython->py-heat-magic) (0.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2>=2.4->nbconvert->jupyter->py-heat-magic) (2.0.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/ben/.local/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->py-heat-magic) (4.4.0)
# Requirement already satisfied: ptyprocess in /usr/lib/python3/dist-packages (from terminado>=0.8.3->notebook->jupyter->py-heat-magic) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/ben/.local/lib/python3.9/site-packages (from argon2-cffi->notebook->jupyter->py-heat-magic) (21.2.0)
# Requirement already satisfied: webencodings in /usr/lib/python3/dist-packages (from bleach->nbconvert->jupyter->py-heat-magic) (0.5.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/ben/.local/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->py-heat-magic) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /home/ben/.local/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->py-heat-magic) (21.4.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/ben/.local/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->py-heat-magic) (1.15.0)
# Requirement already satisfied: pycparser in /home/ben/.local/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->py-heat-magic) (2.21)

# %%
from z3 import *
import csv

# %%
# basic puzzle
word_length = 5

def define_letter_variables():
    return [z3.Int(f"letter_{index}") for index in range(word_length)]

def add_alphabet_modeling_constraints(solver, letter_vars):
    for letter_var in letter_vars:
        solver.add(letter_var >= 0, letter_var <= 25)

    return solver

letter_to_index_map = {letter: index for index, letter in enumerate("abcdefghijklmnopqrstuvwxyz")}
index_to_letter_map = {index: letter for letter, index in letter_to_index_map.items()}

def pretty_print_solution(model, letter_vars):
    word = []
    for index, letter_var in enumerate(letter_vars):
        word.append(index_to_letter_map[model[letter_var].as_long()])

    word = ''.join(word)
    return word

# dictionary
def load_dictionary():
    dictionary = []
    with open('words.csv', newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        dictionary = list(map(lambda x: x[0].strip().lower(), spamreader))
    return dictionary

def add_legal_words_constraints(solver, words, letter_vars):
    all_words_disjunction = []

    for word in words:
        word_conjuction = z3.And([letter_vars[index] == letter_to_index_map[letter] for index, letter in enumerate(word)])
        all_words_disjunction.append(word_conjuction)

    solver.add(z3.Or(all_words_disjunction))

    return solver

# letter frequency
def add_doesnt_contain_letter_constraint(solver, letter_vars, letter):
    for letter_var in letter_vars:
        solver.add(letter_var != letter_to_index_map[letter])

    return solver

def add_contains_letter_constraint(solver, letter_vars, letter):
    solver.add(z3.Or([letter_var == letter_to_index_map[letter] for letter_var in letter_vars]))

    return solver

def add_invalid_position_constraint(solver, letter_vars, letter, position):
    solver.add(letter_vars[position] != letter_to_index_map[letter])

    return solver

def solvingModel(solver, step):
    print("[SOLVING] " + step)
    result = solver.check()
    print(result)

    model = solver.model()
    pretty_print_solution(model, letter_vars)

# subsequent guesses
def add_exact_letter_position_constraint(solver, letter_vars, letter, position):
    solver.add(letter_vars[position] == letter_to_index_map[letter])

    return solver

def add_letter_appears_once_constraint(solver, letter_vars, letter):
    unique_letter_disjunction = []

    for letter_var in letter_vars:
        this_letter_conjunction = [letter_var == letter_to_index_map[letter]]
        for other_letter_var in letter_vars:
            if letter_var == other_letter_var:
                continue
            this_letter_conjunction.append(other_letter_var != letter_to_index_map[letter])
        unique_letter_disjunction.append(z3.And(this_letter_conjunction))

    solver.add(z3.Or(unique_letter_disjunction))

    return solver

# friendlier controlls
def green(solver, letter_vars, letter, position):
    add_exact_letter_position_constraint(solver, letter_vars, letter, position)

def yellow(solver, letter_vars, letter, position):
    add_letter_appears_once_constraint(solver, letter_vars, letter)
    add_invalid_position_constraint(solver, letter_vars, letter, position)

def grey(solver, letter_vars, letter, position):
    add_doesnt_contain_letter_constraint(solver, letter_vars, letter)

def second_grey(solver, letter_vars, letter, position):
    add_invalid_position_constraint(solver, letter_vars, letter, position)

# %%
def add_similar_word_to_main(solver, letter_vars, word):
    if len(word) != word_length: raise Exception('the word is not correct')
    word = word.lower()
    equation = []
    for position, letter in enumerate(word):
        equation.append(
            And(letter_vars[position] != letter_to_index_map[letter], 
                Or([letter_var == letter_to_index_map[letter] for letter_var in letter_vars])))

    solver.add(Or(equation))

    return solver

def add_similar_word_to_clue(solver, letter_vars, clue, main):
    if len(clue) != word_length: raise Exception('the word is not correct')
    clue = clue.lower()
    equation = []
    for position, letter in enumerate(clue):
        is_same_position = letter_vars[position] == letter_to_index_map[letter]
        # at least one siminal letter
        equation.append(Or([letter_var == letter_to_index_map[letter] for letter_var in letter_vars]))

        # can't have the same yellow at the same position
        is_green = letter_to_index_map[letter] == letter_to_index_map[main[position]]
        is_yellow = And(Or([letter_to_index_map[letter] == letter_to_index_map[main_letter] for main_letter in main]), # contains word
                    Not(is_green))

        solver.add(Implies(is_yellow, Not(is_same_position)))

        # can't have a green after a grey/yello
        solver.add(
            Implies(Not(is_green), # not a green
                letter_vars[position] != letter_to_index_map[main[position]]))
                
    solver.add(Or(equation))

    # Can't have an unused previous clue
    for letter in main:
        if letter not in clue:
            add_doesnt_contain_letter_constraint(solver, letter_vars, letter)

    return solver

# %%
# %load_ext line_profiler
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
def find_solution_for_word(word):
    if len(word) != 5: raise Exception('the word is not correct')
    word = word.lower()

    # build basic solver (~60% time)
    solver = Solver()
    letter_vars = define_letter_variables()
    solver = add_alphabet_modeling_constraints(solver, letter_vars)
    words = load_dictionary() 
    solver = add_legal_words_constraints(solver, words, letter_vars)

    # find solution (~40% time)
    solution = [word]
    add_similar_word_to_main(solver, letter_vars, solution[0])
    while solver.check() != unsat:
        # addsimilar word
        # solver.maximize(Sum([If(letter_vars[position] == letter_to_index_map[letter], 1, 0) for position, letter in enumerate(word)]))
    
        model = solver.model()
        similar_word = pretty_print_solution(model, letter_vars)
        solution.append(similar_word)
        add_similar_word_to_clue(solver, letter_vars, similar_word, solution[0])

    return solution


find_solution_for_word("taunt")
# Out:
# ['taunt', 'truth', 'thrum']

# %%
import random
from multiprocessing import Pool

if __name__ == "__main__":
    words = load_dictionary() 

    
    print(len(words))
    choices = words #random.choices(words, k=100)
    with Pool(8) as p:
        solutions = p.map(find_solution_for_word, choices)
        maxSolution = []
        for solution in solutions:
            if len(maxSolution) < len(solution):
                maxSolution = solution
        print(len(maxSolution))
        print(maxSolution) # ~ 3h

# ['thief', 'often', 'steal', 'duvet', 'clove', 'beard', 'enjoy']
# ['zonal', 'extra', 'stake', 'taffy', 'acrid']
# ['fauna', 'urban', 'ascot', 'beach', 'caddy', 'satyr', 'pizza', 'voila', 'opera', 'maybe'] # eroor opera should block
# ['taunt', 'truth', 'tweed', 'twice', 'tempo', 'tepid', 'tiger', 'thief', 'their', 'title', 'tilde', 'style']
# [12] fix: ['taunt', 'truth', 'title', 'tweed', 'twice', 'tempo', 'tepid', 'tiger', 'thief', 'their', 'tilde', 'style']
# given a word to solve
# find the slowest hard solution
# Out:
# 2315
# Process ForkPoolWorker-87:
# Process ForkPoolWorker-88:
# Process ForkPoolWorker-90:
# Exception ignored in:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/ben/Documents/projects/puzzle/z3_jane_wordle.ipynb Cell 7' in <module>
#       <a href='vscode-notebook-cell:/home/ben/Documents/projects/puzzle/z3_jane_wordle.ipynb#ch0000006?line=8'>9</a> choices = words #random.choices(words, k=100)
#      <a href='vscode-notebook-cell:/home/ben/Documents/projects/puzzle/z3_jane_wordle.ipynb#ch0000006?line=9'>10</a> with Pool(8) as p:
# ---> <a href='vscode-notebook-cell:/home/ben/Documents/projects/puzzle/z3_jane_wordle.ipynb#ch0000006?line=10'>11</a>     solutions = p.map(find_solution_for_word, choices)
#      <a href='vscode-notebook-cell:/home/ben/Documents/projects/puzzle/z3_jane_wordle.ipynb#ch0000006?line=11'>12</a>     maxSolution = []
#      <a href='vscode-notebook-cell:/home/ben/Documents/projects/puzzle/z3_jane_wordle.ipynb#ch0000006?line=12'>13</a>     for solution in solutions:
#
# File /usr/lib/python3.9/multiprocessing/pool.py:364, in Pool.map(self, func, iterable, chunksize)
#     <a href='file:///usr/lib/python3.9/multiprocessing/pool.py?line=358'>359</a> def map(self, func, iterable, chunksize=None):
#     <a href='file:///usr/lib/python3.9/multiprocessing/pool.py?line=359'>360</a>     '''
#     <a href='file:///usr/lib/python3.9/multiprocessing/pool.py?line=360'>361</a>     Apply `func` to each element in `iterable`, collecting the results
#     <a href='file:///usr/lib/python3.9/multiprocessing/pool.py?line=361'>362</a>     in a list that is returned.
#     <a href='file:///usr/lib/python3.9/multiprocessing/pool.py?line=362'>363</a>     '''
# --> <a href='file:///usr/lib/python3.9/multiprocessing/pool.py?line=363'>364</a>     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File /usr/lib/python3.9/multiprocessing/pool.py:765, in ApplyResult.get(self, timeout)
#     <a href='file:///usr/lib/python3.9/multiprocessing/pool.py?line=763'>764</a> def get(self, timeout=None):
# --> <a href='file:///usr/lib/python3.9/multiprocessing/pool.py?line=764'>765</a>     self.wait(timeout)
#     <a href='file:///usr/lib/python3.9/multiprocessing/pool.py?line=765'>766</a>     if not self.ready():
#     <a href='file:///usr/lib/python3.9/multiprocessing/pool.py?line=766'>767</a>         raise TimeoutError
#
# File /usr/lib/python3.9/multiprocessing/pool.py:762, in ApplyResult.wait(self, timeout)
#     <a href='file:///usr/lib/python3.9/multiprocessing/pool.py?line=760'>761</a> def wait(self, timeout=None):
# --> <a href='file:///usr/lib/python3.9/multiprocessing/pool.py?line=761'>762</a>     self._event.wait(timeout)
#
# File /usr/lib/python3.9/threading.py:574, in Event.wait(self, timeout)
#     <a href='file:///usr/lib/python3.9/threading.py?line=571'>572</a> signaled = self._flag
#     <a href='file:///usr/lib/python3.9/threading.py?line=572'>573</a> if not signaled:
# --> <a href='file:///usr/lib/python3.9/threading.py?line=573'>574</a>     signaled = self._cond.wait(timeout)
#     <a href='file:///usr/lib/python3.9/threading.py?line=574'>575</a> return signaled
#
# File /usr/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     <a href='file:///usr/lib/python3.9/threading.py?line=309'>310</a> try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     <a href='file:///usr/lib/python3.9/threading.py?line=310'>311</a>     if timeout is None:
# --> <a href='file:///usr/lib/python3.9/threading.py?line=311'>312</a>         waiter.acquire()
#     <a href='file:///usr/lib/python3.9/threading.py?line=312'>313</a>         gotit = True
#     <a href='file:///usr/lib/python3.9/threading.py?line=313'>314</a>     else:
#
# KeyboardInterrupt:

# %%
# for each words
# for each letters
# rules
# 1. if a letter from the main isn't used it can never be used
# 2. can't have the same yellow at the same position
# 3. can't have a green after a grey/yello

# heuristics
# - sort candiates by most green, then most yellow
